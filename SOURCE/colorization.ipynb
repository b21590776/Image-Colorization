# %% [markdown]
# **Drive için authentication adımları**

# %% [markdown]
# **Drive'ı mount etmek için** <br>
#
#
# Bu aşamadan sonra Files sekmesinde drive'daki bütün soyalar gözükecektir. <br>
# **/content dizini Colab'ın ana (root) dizinidir. **

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !ls /content/drive/My\ Drive/colorization_tensorflow/DATASET/Gravur/train

# %%
import tensorflow as tf
tf.test.gpu_device_name()

# %%
# !python3 /content/drive/My\ Drive/colorization_tensorflow/SOURCE/main.py

# %%
import os 
import cv2
flist = []
for folder in os.listdir("/content/drive/My Drive/colorization_tensorflow/DATASET/Gravur/train"):
    for file in os.listdir("/content/drive/My Drive/colorization_tensorflow/DATASET/Gravur/train" + "/" + folder):
        flist.append("/content/drive/My Drive/colorization_tensorflow/DATASET/Gravur/train" + "/" + folder + "/" + file)

for i in flist:
  try:
    img = cv2.imread(i, 3)
    labimg = cv2.cvtColor(cv2.resize(img, (128, 128)), cv2.COLOR_BGR2Lab)
  except:
    print(i)
# Out:
# /content/drive/My Drive/colorization_tensorflow/DATASET/Gravur/train/red_dress /80.jpeg

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

imgpath = "/content/drive/My Drive/colorization_tensorflow/DATASET/Gravur/elbisetest/100.jpg"
img = cv2.imread(imgpath)
plt.plot()
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2GRAY))
plt.show()
